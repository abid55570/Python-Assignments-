# %% [markdown]
# <a href="https://colab.research.google.com/github/abid55570/Python-Assignments-/blob/main/5th_March_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
p = figure()
p.line(x, y)
output_notebook()
show(p)

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Prepare data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure object
p = figure()

# Add glyphs to the figure
p.circle(x, y, size=10, color='blue', alpha=0.8)  # Add circle glyphs
p.line(x, y, line_width=2, color='red', alpha=0.8)  # Add line glyphs

# Customize the plot
p.title.text = "Example Plot"
p.xaxis.axis_label = "X-axis"
p.yaxis.axis_label = "Y-axis"

# Display the plot in a Jupyter Notebook
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="91a463d9-effe-4f9d-a06a-71b11bd0b501" data-root-id="1002"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Prepare data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure object
p = figure()

# Add glyphs to the figure
p.circle(x, y, size=10, color='blue', alpha=0.8)

# Customize the appearance
p.title.text = "Customized Plot"
p.xaxis.axis_label = "X-axis"
p.yaxis.axis_label = "Y-axis"
p.xaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.xgrid.visible = True
p.ygrid.visible = True
p.background_fill_color = "lightgray"
p.border_fill_color = "white"
p.border_fill_alpha = 0.5
p.outline_line_width = 2

# Display the plot in a Jupyter Notebook
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="3d92d224-f66b-4562-8d0d-9275be532c1d" data-root-id="1124"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# The Bokeh server is a powerful tool provided by the Bokeh library that allows you to create interactive plots that can be updated in real time. It enables you to build web applications or dashboards that provide dynamic and interactive visualizations.
#
# The Bokeh server works by running a Python script that creates the plot and defines the desired interactivity. The server then hosts the plot as a web application, which can be accessed through a web browser. With the Bokeh server, you can update the plot in response to user interactions, changes in data, or any other event.

# %%
# import he necessary modules for bokeh
from bokeh.plotting import figure, curdoc
from bokeh.models import ColumnDataSource
from bokeh.layouts import row

# create a figure and define the initial plot

p = figure(...)  # Create a figure with desired settings
source = ColumnDataSource(...)  # Define the data source for the plot
glyph = p.circle(...)  # Add glyphs to the plot using the data source

# Define the update function:
def update():
    # Update the data source or properties of the glyphs
    source.data = new_data
    glyph.property = new_value

# Add the update function to the document:
curdoc().add_periodic_callback(update, milliseconds)  # Call the update function periodically


Run the Bokeh server:
bokeh serve --show your_script.py

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# To embed a Bokeh plot into a web page or dashboard using Flask or Django, you can follow these general steps:
#
# Set up your Flask or Django application:
#
# For Flask, create a Flask application and set up the necessary routes and views.
# For Django, create a Django project and app, and configure the URL routing.
# Create a Bokeh plot in your Python code:
#
# Import the required Bokeh modules: from bokeh.plotting import figure, output_file, show.
# Create a figure and add glyphs, customize the plot as desired.
# Use output_file() to specify the output file path where the Bokeh plot will be saved.
# Save the Bokeh plot as an HTML file:
#
# Use show() to display the plot in a browser window and save it as an HTML file.
# Specify the path where the HTML file will be saved: output_file('path/to/your/plot.html').
# Integrate the Bokeh plot into your web page or dashboard template:
#
# In your Flask or Django template file, include the HTML file containing the Bokeh plot.
# Use appropriate template syntax to render the HTML file within the page.
# Render the web page or dashboard using Flask or Django:
#
# In Flask, return the rendered template using render_template() in your route or view function.
# In Django, render the template within a view function and return an HttpResponse object.
# Start the Flask or Django development server and view the web page:
#
# Run your Flask or Django application using the appropriate command.
# Open a browser and navigate to the specified URL to view the web page or dashboard.
